# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
# Define the simplified AlexNet model
class SimpleAlexNet(nn.Module):
    def __init__(self, num_classes=7):
        super(SimpleAlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(128 * 6 * 6, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), 128 * 6 * 6)
        x = self.classifier(x)
        return x

# Set device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("mps")

# Define transformations
transform = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the dataset
dataset = ImageFolder('images/train', transform=transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Initialize the model
model = SimpleAlexNet(num_classes=7).to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 40
train_loss_history = []
val_loss_history = []
train_acc_history = []
val_acc_history = []

for epoch in range(num_epochs):
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    model.train()
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(dataloader)
    train_accuracy = correct_train / total_train

    model.eval()
    running_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss = running_loss / len(dataloader)
    val_accuracy = correct_val / total_val

    train_loss_history.append(train_loss)
    val_loss_history.append(val_loss)
    train_acc_history.append(train_accuracy)
    val_acc_history.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs} Train Loss: {train_loss:.4f} Val Loss: {val_loss:.4f} "
          f"Train Acc: {train_accuracy:.4f} Val Acc: {val_accuracy:.4f}")

# Save the trained model
torch.save(model.state_dict(), 'models/simple_alexnet_model_40epcohs_extended.pth')

# Plot loss and accuracy curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_loss_history, label='Train Loss')
plt.plot(val_loss_history, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc_history, label='Train Accuracy')
plt.plot(val_acc_history, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/40 Train Loss: 1.5644 Val Loss: 1.2986 Train Acc: 0.3825 Val Acc: 0.4989
# Epoch 2/40 Train Loss: 1.2941 Val Loss: 1.1676 Train Acc: 0.5038 Val Acc: 0.5588
# Epoch 3/40 Train Loss: 1.1694 Val Loss: 1.0268 Train Acc: 0.5589 Val Acc: 0.6098
# Epoch 4/40 Train Loss: 1.0792 Val Loss: 0.9295 Train Acc: 0.5904 Val Acc: 0.6445
# Epoch 5/40 Train Loss: 0.9910 Val Loss: 0.8107 Train Acc: 0.6256 Val Acc: 0.7111
# Epoch 6/40 Train Loss: 0.8993 Val Loss: 0.7206 Train Acc: 0.6627 Val Acc: 0.7452
# Epoch 7/40 Train Loss: 0.8026 Val Loss: 0.5688 Train Acc: 0.6965 Val Acc: 0.8065
# Epoch 8/40 Train Loss: 0.7257 Val Loss: 0.4896 Train Acc: 0.7256 Val Acc: 0.8450
# Epoch 9/40 Train Loss: 0.6445 Val Loss: 0.4031 Train Acc: 0.7585 Val Acc: 0.8755
# Epoch 10/40 Train Loss: 0.5734 Val Loss: 0.3361 Train Acc: 0.7859 Val Acc: 0.8961
# Epoch 11/40 Train Loss: 0.5148 Val Loss: 0.2716 Train Acc: 0.8108 Val Acc: 0.9223
# Epoch 12/40 Train Loss: 0.4732 Val Loss: 0.2497 Train Acc: 0.8275 Val Acc: 0.9273
# Epoch 13/40 Train Loss: 0.4352 Val Loss: 0.1945 Train Acc: 0.8403 Val Acc: 0.9459
# Epoch 14/40 Train Loss: 0.3957 Val Loss: 0.1533 Train Acc: 0.8521 Val Acc: 0.9590
# Epoch 15/40 Train Loss: 0.3740 Val Loss: 0.1443 Train Acc: 0.8606 Val Acc: 0.9633
# Epoch 16/40 Train Loss: 0.3494 Val Loss: 0.1448 Train Acc: 0.8743 Val Acc: 0.9604
# Epoch 17/40 Train Loss: 0.3394 Val Loss: 0.1226 Train Acc: 0.8756 Val Acc: 0.9683
# Epoch 18/40 Train Loss: 0.3104 Val Loss: 0.0962 Train Acc: 0.8849 Val Acc: 0.9762
# Epoch 19/40 Train Loss: 0.3014 Val Loss: 0.0935 Train Acc: 0.8894 Val Acc: 0.9764
# Epoch 20/40 Train Loss: 0.2985 Val Loss: 0.0811 Train Acc: 0.8915 Val Acc: 0.9803
# Epoch 21/40 Train Loss: 0.2860 Val Loss: 0.0732 Train Acc: 0.8961 Val Acc: 0.9797
# Epoch 22/40 Train Loss: 0.2752 Val Loss: 0.0706 Train Acc: 0.8987 Val Acc: 0.9828
# Epoch 23/40 Train Loss: 0.2601 Val Loss: 0.0745 Train Acc: 0.9065 Val Acc: 0.9797
# Epoch 24/40 Train Loss: 0.2582 Val Loss: 0.0540 Train Acc: 0.9085 Val Acc: 0.9870
# Epoch 25/40 Train Loss: 0.2533 Val Loss: 0.0533 Train Acc: 0.9104 Val Acc: 0.9858
# Epoch 26/40 Train Loss: 0.2404 Val Loss: 0.0525 Train Acc: 0.9141 Val Acc: 0.9847
# Epoch 27/40 Train Loss: 0.2426 Val Loss: 0.0514 Train Acc: 0.9109 Val Acc: 0.9851
# Epoch 28/40 Train Loss: 0.2477 Val Loss: 0.0517 Train Acc: 0.9125 Val Acc: 0.9891
# Epoch 29/40 Train Loss: 0.2291 Val Loss: 0.0451 Train Acc: 0.9184 Val Acc: 0.9886
# Epoch 30/40 Train Loss: 0.2254 Val Loss: 0.0525 Train Acc: 0.9196 Val Acc: 0.9843
# Epoch 31/40 Train Loss: 0.2191 Val Loss: 0.0407 Train Acc: 0.9211 Val Acc: 0.9900
# Epoch 32/40 Train Loss: 0.2095 Val Loss: 0.0373 Train Acc: 0.9256 Val Acc: 0.9907
# Epoch 33/40 Train Loss: 0.2175 Val Loss: 0.0326 Train Acc: 0.9205 Val Acc: 0.9918
# Epoch 34/40 Train Loss: 0.2184 Val Loss: 0.0402 Train Acc: 0.9224 Val Acc: 0.9898
# Epoch 35/40 Train Loss: 0.2000 Val Loss: 0.0343 Train Acc: 0.9287 Val Acc: 0.9915
# Epoch 36/40 Train Loss: 0.2035 Val Loss: 0.0341 Train Acc: 0.9277 Val Acc: 0.9922
# Epoch 37/40 Train Loss: 0.2015 Val Loss: 0.0330 Train Acc: 0.9297 Val Acc: 0.9920
# Epoch 38/40 Train Loss: 0.1923 Val Loss: 0.0319 Train Acc: 0.9314 Val Acc: 0.9906
# Epoch 39/40 Train Loss: 0.2014 Val Loss: 0.0306 Train Acc: 0.9287 Val Acc: 0.9922
# Epoch 40/40 Train Loss: 0.1905 Val Loss: 0.0324 Train Acc: 0.9340 Val Acc: 0.9898

# %% [markdown]
# ### Test

# %%
# Load the test dataset
test_dataset = ImageFolder('images/validation', transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Initialize the model
model = SimpleAlexNet(num_classes=7).to(device)

# Load the trained model weights
model.load_state_dict(torch.load('models/simple_alexnet_model_40epcohs_extended.pth'))

# Evaluate the model
model.eval()
total_correct = 0
total_samples = 0
predictions = []

with torch.no_grad():
    for images, labels in test_dataloader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        predictions.extend(predicted.cpu().numpy())
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()

accuracy = total_correct / total_samples
print(f"Test Accuracy: {accuracy:.4f}")

# Convert predictions and labels to numpy arrays
predictions = np.array(predictions)
labels = test_dataset.targets

# Plot a confusion matrix
num_classes = len(test_dataset.classes)
confusion_matrix = np.zeros((num_classes, num_classes))
for i in range(len(predictions)):
    confusion_matrix[labels[i], predictions[i]] += 1

plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, cmap='Blues')
plt.colorbar()
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(np.arange(num_classes), test_dataset.classes, rotation=45)
plt.yticks(np.arange(num_classes), test_dataset.classes)
plt.tight_layout()
plt.show()

# Plot a few example predictions
plt.figure(figsize=(12, 6))
for i in range(6):
    index = np.random.randint(len(predictions))
    image, label = test_dataset[index]
    image = image.permute(1, 2, 0)  # Reshape image tensor for visualization
    predicted_class = test_dataset.classes[predictions[index]]
    true_class = test_dataset.classes[label]
    
    plt.subplot(2, 3, i+1)
    plt.imshow(image)
    plt.title(f'Predicted: {predicted_class}\nTrue: {true_class}')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 0.5841
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
